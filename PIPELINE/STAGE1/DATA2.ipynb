# %%
# !python DATA2.py
# Out:
# === TRAIN STAGE1 BUILD ===
# saved: ../../DATA/dataset/TRAIN_stage1
# shape: (609658, 12)
# n_features: 10
# mem(MB): 19.77
# === TEST STAGE1 BUILD ===
# saved: ../../DATA/dataset/TEST_stage1
# shape: (114209, 12)
# n_features: 10
# mem(MB): 3.7

# %%
import pandas as pd

train_out = pd.read_parquet("../../DATA/dataset/TRAIN_stage1")
test_out  = pd.read_parquet("../../DATA/dataset/TEST_stage1")

print("TRAIN cols:", train_out.columns.tolist())
print("TEST  cols:", test_out.columns.tolist())

print("TRAIN dtypes:\n", train_out.dtypes)
print("TEST  dtypes:\n", test_out.dtypes)

print("TRAIN shape:", train_out.shape, "TEST shape:", test_out.shape)
# Out:
# TRAIN cols: ['id', 'fraud', 'mcc_smoothed_risk', 'mcc_risk_level', 'hour_sin', 'hour_cos', 'weekday', 'month_sin', 'is_risky_wd_hour', 'is_risky_month', 'log_abs_amount', 'err_bad_cvv']
# TEST  cols: ['id', 'fraud', 'mcc_smoothed_risk', 'mcc_risk_level', 'hour_sin', 'hour_cos', 'weekday', 'month_sin', 'is_risky_wd_hour', 'is_risky_month', 'log_abs_amount', 'err_bad_cvv']
# TRAIN dtypes:
#  id                     int64
# fraud                   int8
# mcc_smoothed_risk    float32
# mcc_risk_level          int8
# hour_sin             float32
# hour_cos             float32
# weekday                 int8
# month_sin            float32
# is_risky_wd_hour        int8
# is_risky_month          int8
# log_abs_amount       float32
# err_bad_cvv             int8
# dtype: object
# TEST  dtypes:
#  id                     int64
# fraud                   int8
# mcc_smoothed_risk    float32
# mcc_risk_level          int8
# hour_sin             float32
# hour_cos             float32
# ...
