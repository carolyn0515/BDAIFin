# %%
# %load_ext autoreload
# %autoreload 2
import PIPELINE.STAGE2.DATA2 as DATA2
DATA2.build_test_stage2_from_review_ids()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# saved: ../../DATA/dataset/TEST_stage2
# shape: (1026, 24)
# n_features: 22
# mem(MB): 0.07
# stage1_added_cols: 10
# stage2_cols: 12

# %%
import pandas as pd

out_path = "../../DATA/dataset/TEST_stage2"
df_out = pd.read_parquet(out_path)

print("saved_path:", out_path)
print("shape:", df_out.shape)
print("cols:", df_out.columns.tolist())
df_out.head()
# Out:
# saved_path: ../../DATA/dataset/TEST_stage2
# shape: (1026, 24)
# cols: ['id', 'fraud', 'card_fraud_last3', 'client_error_last3', 'client_mcc_is_new', 'vel_x_merchant_new', 'vel_x_mcc_risk', 'amount_limit_ratio', 'limit_ratio_extreme', 'merchant_change_last5_x_amount_limit_ratio', 'log_interval_dev', 'seconds_since_prev_tx', 'credit_limit', 'is_refund', 'mcc_smoothed_risk', 'mcc_risk_level', 'hour_sin', 'hour_cos', 'weekday', 'month_sin', 'is_risky_wd_hour', 'is_risky_month', 'log_abs_amount', 'err_bad_cvv']
#          id  fraud  card_fraud_last3  client_error_last3  client_mcc_is_new  \
# 0  17269523      0                 0                   0                  1
# 1  17614656      0                 0                   0                  0
# 2  18424729      1                 0                   0                  1
# 3  18688068      1                 0                   0                  1
# 4  18688335      1                 1                   1                  0
#
# ...
